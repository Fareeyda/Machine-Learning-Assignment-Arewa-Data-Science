# %% [markdown]
# Visualize some more Time Series

# %% [markdown]
# Instructions

# %% [markdown]
# You've begun to learn about Time Series Forecasting by looking at the type of data that requires this special modeling. You've visualized some data around energy. Now, look around for some other data that would benefit from Time Series Forecasting. Find three examples (try Kaggle and Azure Open Datasets) and create a notebook to visualize them. Notate any special characteristics they have (seasonality, abrupt changes, or other trends) in the notebook.

# %% [markdown]
# Using the Screentime - App Details.csv Dataset from Kaggle

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from common.utils import load_data
import seaborn as sns
# %matplotlib inline
import datetime
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error,r2_score

# %% [markdown]
# Data Loading

# %%
screentime=pd.read_csv('../Data/Screentime - App Details.csv')
screentime.head(10)
# Out:
#          Date  Usage  Notifications  Times opened        App
# 0  08/26/2022     38             70            49  Instagram
# 1  08/27/2022     39             43            48  Instagram
# 2  08/28/2022     64            231            55  Instagram
# 3  08/29/2022     14             35            23  Instagram
# 4  08/30/2022      3             19             5  Instagram
# 5  08/31/2022     19             25            20  Instagram
# 6  09/01/2022     44             23            57  Instagram
# 7  09/02/2022     16             28            22  Instagram
# 8  09/03/2022     27             15            25  Instagram
# 9  09/04/2022     72             29            30  Instagram

# %%
import pandas as pd
screentime = pd.read_csv('../Data/Screentime - App Details.csv',index_col = 'Date',parse_dates= ['Date']).drop(['App','Usage','Times opened'],axis=1)
screentime.head()
# Out:
#             Notifications
# Date
# 2022-08-26             70
# 2022-08-27             43
# 2022-08-28            231
# 2022-08-29             35
# 2022-08-30             19

# %%
screentime['Time'] = np.arange(len(screentime.index))

screentime.head()
# Out:
#             Notifications  Time
# Date
# 2022-08-26             70     0
# 2022-08-27             43     1
# 2022-08-28            231     2
# 2022-08-29             35     3
# 2022-08-30             19     4

# %%
screentime['Notifications'].plot()
# Out:
# <Axes: xlabel='Date'>
