# %% [markdown]
# Instructions

# %% [markdown]
# In this lesson you were shown how to build a model using both Linear and Polynomial Regression. Using this knowledge, find a dataset or use one of Scikit-learn's built-in sets to build a fresh model. Explain in your notebook why you chose the technique you did, and demonstrate your model's accuracy. If it is not accurate, explain why.

# %% [markdown]
# Using salary_Data From Kaggle

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

salary_Data = pd.read_csv('../Week 04 _ Regression/Linear/salary_Data.csv')

salary_Data.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
salary_Data.shape
# Out:
# (30, 2)

# %%
salary_Data.tail()
# Out:
#     YearsExperience  Salary
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
salary_Data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
X = np.array([salary_Data.YearsExperience]).T
y = np.array([salary_Data.Salary]).T

print('The shape of input: {}'.format(X.shape))
print('The shape of target: {}'.format(y.shape))
# Out:
# The shape of input: (30, 1)
# The shape of target: (30, 1)

# %%
salary_Data.plot(kind = 'scatter', x = 'YearsExperience', y = 'Salary')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
y_pred = model.predict(X_test)
y_pred
# Out:
# array([[ 40817.78327049],
#        [123188.08258899],
#        [ 65154.46261459],
#        [ 63282.41035735],
#        [115699.87356004],
#        [108211.66453108],
#        [116635.89968866],
#        [ 64218.43648597],
#        [ 76386.77615802]])

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, model.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
# Visualising the Test set results
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, model.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
#showing the intercept point
model.intercept_
# Out:
# array([26777.3913412])

# %%
#showing the coefficient 
model.coef_
# Out:
# array([[9360.26128619]])

# %%
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 23370078.800832972
